# %% [markdown]
# #Importando aquivo .py

# %%
import sys
sys.path.insert(0, '/content/drive/MyDrive/ColabNotebooks/')

import pratica15

# %% [markdown]
# #Teste do módulo pratica15.py

# %% [markdown]
# #Dicionário declarado no módulo:

# %%
print (pratica15.dicionario)
# Out:
# {'nome': 'Lang Python', 'data_nascimento': '25/12/1989'}

# %% [markdown]
# #Função declarada no módulo:

# %%
pratica15.ola("Jupyter Notebook")
# Out:
# Olá, Jupyter Notebook!

# %% [markdown]
# #Classe declarada no módulo:

# %%
p = pratica15.Pessoa("Ana Conda","17/07/2012")
p.cumprimento()
# Out:
# Olá, Ana Conda!
# Você nasceu em 17/07/2012. Parabéns!

# %% [markdown]
# #Objeto instanciado no módulo:

# %%
print(pratica15.objeto_pessoa.nome)
# Out:
# Google Colab

# %% [markdown]
# #Dicionário declarado no módulo:

# %%
d = pratica15.dicionario
print(d)
# Out:
# {'nome': 'Lang Python', 'data_nascimento': '25/12/1989'}

# %% [markdown]
# #Função declarada no módulo:

# %%
o = pratica15.ola ("Jupyter Notebook")
print(o)
# Out:
# Olá, Jupyter Notebook!
# None

# %% [markdown]
# #Classe declarada no módulo:

# %%
c = pratica15.Pessoa ("Ana Conda", "17/07/2012").cumprimento ()
print(c)
# Out:
# Olá, Ana Conda!
# Você nasceu em 17/07/2012. Parabéns!
# None

# %% [markdown]
# #Objeto instanciado no módulo:

# %%
n = pratica15.objeto_pessoa.nome
print(n)

# %% [markdown]
# # Renomeando "Alias"

# %%
import pratica15 as p15

# %% [markdown]
# #Dicionário declarado no módulo:

# %%
print (p15.dicionario)
# Out:
# {'nome': 'Lang Python', 'data_nascimento': '25/12/1989'}

# %% [markdown]
# #Função declarada no módulo:

# %%
p15.ola ("Jupyter Notebook")
# Out:
# Olá, Jupyter Notebook!

# %% [markdown]
# #Classe declarada no módulo:

# %%
p = p15.Pessoa ("Ana Conda", "17/07/2012")
p.cumprimento ()
# Out:
# Olá, Ana Conda!
# Você nasceu em 17/07/2012. Parabéns!

# %% [markdown]
# #From

# %%
from pratica15 import dicionario

# %% [markdown]
# #Dicionário declarado no módulo:

# %%
print (dicionario)
# Out:
# {'nome': 'Lang Python', 'data_nascimento': '25/12/1989'}

# %% [markdown]
# #dir()

# %%
import pratica15

# %% [markdown]
# #Nomes dos membros do módulo:

# %%
nomes = dir(pratica15)
print(nomes)
# Out:
# ['Pessoa', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'dicionario', 'objeto_pessoa', 'ola']

# %% [markdown]
# #Modulos Prontos

# %%
import platform
sistema_operacional = platform.system()
print ("Sistema operacional em que o notebook está sendo executado:", sistema_operacional)
# Out:
# Sistema operacional em que o notebook está sendo executado: Linux
